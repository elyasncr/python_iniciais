# %% [markdown]
# <a href="https://colab.research.google.com/github/elyasncr/python_iniciais/blob/main/Prova_final_cisco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(¡Hola Mundo!)
# Out:
#   File "<ipython-input-1-a839ae6890d0>", line 1
#     print(¡Hola Mundo!)
#           ^
# SyntaxError: invalid character '¡' (U+00A1)

# %%
def function_1(a):
    return None
 
 
def function_2(a):
    return function_1(a) * function_1(a)
 
 
print(function_2(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-b5ea012c8eb0> in <cell line: 9>()
#       7
#       8
# ----> 9 print(function_2(2))
#
# <ipython-input-2-b5ea012c8eb0> in function_2(a)
#       4
#       5 def function_2(a):
# ----> 6     return function_1(a) * function_1(a)
#       7
#       8
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'NoneType'

# %%
print(1 // 2)
# Out:
# 0

# %%
def func(a, b):
    return b ** a
 
 
print(func(b=2, 2))
# Out:
#   File "<ipython-input-4-968707335caa>", line 5
#     print(func(b=2, 2))
#                      ^
# SyntaxError: positional argument follows keyword argument

# %%
z = 0
y = 10
x = y < z and z > y or y < z and z < y

print(x)
# Out:
# False

# %%
my_list = [x * x for x in range(5)]
 
 
def fun(lst):
    del lst[lst[2]]
    return lst
 
 
print(fun(my_list))
# Out:
# [0, 1, 4, 9]

# %%
x = 1
y = 2
x, y, z = x, x, y
z, y, z = x, y, z
 
print(x, y, z)
# Out:
# 1 1 2

# %%
a = 1
b = 0
a = a ^ b
b = a ^ b
a = a ^ b
 
print(a, b)
# Out:
# 0 1

# %%
def fun(x):
    if x % 2 == 0:
        return 1
    else:
        return 2
 
 
print(fun(fun(2)))
# Out:
# 2

# %%
nums = [1, 2, 3]
vals = nums
del vals[:]

print(vals)
# Out:
# []

# %%
x = int(input())
y = int(input())
x = x % y
x = x % y
y = y % x
print(y)
# Out:
# 3
# 2
# 0

# %%
y = input()
x = input()
print(x + y)
# Out:
# 3
# 6
# 63

# %%
print("a", "b", "c", sep="sep")
# Out:
# asepbsepc

# %%
x = 1 // 5 + 1 / 5
print(x)
# Out:
# 0.2

# %%
x = float(input())
y = float(input())
print(y ** (1 / x))
# Out:
# 2
# 4
# 2.0

# %%
dct = {'one': 'two', 'three': 'one', 'two': 'three'}
v = dct['three']
 
for k in range(len(dct)):
    v = dct[v]
 
print(v)
# Out:
# one

# %%
lst = [i for i in range(-1, -2)]
print(len(lst))
# Out:
# 0

# %%
def fun(x, y):
    if x == y:
        return x
    else:
        return fun(x, y-1)
 
 
print(fun(0, 3))
# Out:
# 0

# %%
i = 0
while i < i + 2 :
    i += 1
    print("*")
else:
    print("*")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# ...

# %%
tup = (1, 2, 4, 8)
tup = tup[-2:-1]
tup = tup[-1]
print(tup)
# Out:
# 4

# %%
dd = {"1": "0", "0": "1"}
for x in dd.vals():
    print(x, end="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-488ad3b16617> in <cell line: 2>()
#       1 dd = {"1": "0", "0": "1"}
# ----> 2 for x in dd.vals():
#       3     print(x, end="")
#
# AttributeError: 'dict' object has no attribute 'vals'

# %%
dct = {}
dct['1'] = (1, 2)
dct['2'] = (2, 1)
 
for x in dct.keys():
    print(dct[x][1], end="")
# Out:
# 21

# %%
def fun(inp=2, out=3):
    return inp * out
 
 
print(fun(out=2))
# Out:
# 4

# %%
lst = [[x for x in range(3)] for y in range(3)]
 
for r in range(3):
    for c in range(3):
        if lst[r][c] % 2 != 0:
            print("#")
# Out:
# #
# #
# #

# %%
try:
    value = input("Digite um valor: ")
    print(int(value)/len(value))
except ValueError:
    print("Entrada ruim...")
except ZeroDivisionError:
    print("Entrada muito ruim...")
except TypeError:
    print("Muito, muito ruim entrada...")
except:
    print("Booo!")
# Out:
# Digite um valor: 0
# 0.0

# %%
try:
    print(5/0)
    break
except:
    print("Desculpe, algo deu errado...")
except (ValueError, ZeroDivisionError):
    print("Muito ruim...")
# Out:
#   File "<ipython-input-30-18a702306316>", line 3
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
foo = (1, 2, 3)
foo.index(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-32ee9e0f2bc2> in <cell line: 2>()
#       1 foo = (1, 2, 3)
# ----> 2 foo.index(0)
#
# ValueError: tuple.index(x): x not in tuple
